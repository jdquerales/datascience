# %%
# Ordinary Differential Equations
# This notebook includes an implementation of the examples in Chapter 8 of Python for Scientists Book by J. Stewart
# Author: José Querales
# 7th April 2020

# %%
# The harmonic oscillator

import numpy as np
from scipy.integrate import odeint

odeint(lambda y,t:y, 1, [0,1])

# here we have used an anonymous function f(y,t) = y as the first argument. The second argument is the initial
# y-value. The third and final argument is the list consisting of the (mandatory) initial t-value and the final value,
# which is coerced implicitly to a Numpy array of floats. The output consists of the t- and y-arrays with the initial
# values omitted

# The documentation says that this routine solves first order differential equations. This means that we need to
# recast our problem as a first order system. To do this, we write out a vector of unknowns.
# Out:
# array([[1.        ],
#        [2.71828193]])

# %%
# Now we will solve a simple example of a system of equations. The problem is the simple harmonic motion,

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %matplotlib notebook

# We can now write out the derivative, or the right hand side of the previous equation 
# assuming we give our vector Y
as input:
def rhs(Y, t, omega):
    y, ydot = Y
    return ydot, -omega**2*y


t_arr = np.linspace(0, 2*np.pi, 101)
y_init = [1, 0]

omega = 2.0

y_arr = odeint(rhs, y_init, t_arr, args = (omega,) )

y, ydot = y_arr[:, 0], y_arr[:, 1]

fig = plt.figure()

ax1 = fig.add_subplot(121)
ax1.plot(t_arr, y, t_arr, ydot)
ax1.set_xlabel('t')
ax1.set_ylabel('y and ydot')

ax2 = fig.add_subplot(122)
ax2.plot(y , ydot)
ax2.set_xlabel('y')
ax2.set_ylabel('ydot')

plt.suptitle("Solution curve when omega = %5g" % omega)
fig.tight_layout()

fig.subplots_adjust(top=0.90)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# let's explore the symbolic solution for that differential equation using SymPy

import sys
sys.path.append('/usr/local/lib/python3.7/site-packages') 
import sympy as sy

sy.init_printing()

m, k, x_0, xdot_0, omega_0, t = sy.symbols('m, k, x_0, xdot_0, omega_0, t')
x = sy.Function('x')

sol = sy.dsolve(sy.Derivative(x(t), t, 2) + omega_0**2 * x(t))
sol
# Out:
#            -ⅈ⋅ω₀⋅t       ⅈ⋅ω₀⋅t
# x(t) = C₁⋅ℯ        + C₂⋅ℯ

# %%
# define our initial conditions and solve for them:

ics = [sy.Eq(sol.args[1].subs(t, 0), x_0), sy.Eq(sol.args[1].diff(t).subs(t, 0), xdot_0)]
ics
# Out:
# [C₁ + C₂ = x₀, -ⅈ⋅C₁⋅ω₀ + ⅈ⋅C₂⋅ω₀ = ẋ₀]

# %%
solved_ics = sy.solve(ics)
solved_ics
# Out:
# ⎡⎧    ω₀⋅x₀ + ⅈ⋅ẋ₀      ω₀⋅x₀ - ⅈ⋅ẋ₀⎫⎤
# ⎢⎨C₁: ────────────, C₂: ────────────⎬⎥
# ⎣⎩        2⋅ω₀              2⋅ω₀    ⎭⎦

# %%
full_sol = sol.subs(solved_ics[0])
full_sol
# Out:
#                        ⅈ⋅ω₀⋅t                   -ⅈ⋅ω₀⋅t
#        (ω₀⋅x₀ - ⅈ⋅ẋ₀)⋅ℯ         (ω₀⋅x₀ + ⅈ⋅ẋ₀)⋅ℯ
# x(t) = ────────────────────── + ───────────────────────
#                 2⋅ω₀                      2⋅ω₀

# %%
# We'll use a value of ω0
# equal to 2 (it's often helpful to not choose a value of 1 for constants to spot mistakes early).

case1 = sy.simplify(full_sol.subs({x_0:1, xdot_0:0, omega_0:2}))
case1
# Out:
# x(t) = cos(2⋅t)

# %%
sy.plot(case1.rhs)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
case2 = sy.simplify(full_sol.subs({x_0:0, xdot_0:1, omega_0:2}))
case2
# Out:
#        sin(2⋅t)
# x(t) = ────────
#           2

# %%
sy.plot(case2.rhs)
# Out:
# <img src="data:image/png;base64,..." width="640">
